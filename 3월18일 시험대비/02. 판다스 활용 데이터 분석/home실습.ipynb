# %%
shoe={
   'brand': "Nike",
    'size': 270,
    'color': "black"
}

print(shoe['brand'])
# Out:
# Nike

# %%
product={
    '이름':'아메리카노',
    '가격': 4000,
}
product['재고'] = 50
product['가격'] = 15000
print(product)
# Out:
# {'이름': '아메리카노', '가격': 15000, '재고': 50}

# %%
member = {
  '이름': '이순신',
  '나이': 25,
  '연락처': '010-1234-5678'
}
del member['연락처']

# %%
school = {
  '학교명': '한국고등학교',
  '학생수': 500,
  '과목': ['수학', '영어', '과학'],
  '선생님': [
    {'이름': '김선생', '담당': '수학'},
    {'이름': '박선생', '담당': '영어'}
  ]
}

print(school['과목'][1])
print(len(school['선생님']))
print(school['선생님'][1]['담당'])
school['선생님'][0]['경력'] =10
print(school)
# Out:
# 영어
# 2
# 영어
# {'학교명': '한국고등학교', '학생수': 500, '과목': ['수학', '영어', '과학'], '선생님': [{'이름': '김선생', '담당': '수학', '경력': 10}, {'이름': '박선생', '담당': '영어'}]}
